# %% [markdown]
# # 🚦 Traffic Light RL Control - Interactive Notebook
#
# This notebook provides an interactive exploration of the Traffic Light RL project.
# You can train agents, visualize results, and experiment with different configurations.

# %%
# Import necessary libraries
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

# Import project modules
from src.envs.traffic_env import TrafficLightEnv
from src.agents.modern_agents import TrafficLightAgent, RainbowDQNAgent
from src.utils.config import Config
from src.utils.visualization import RLVisualizer

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("✅ All imports successful!")
